# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\Naresh\OneDrive\Desktop\Rooman\ai4i2020_cleaned.csv')

print(df.columns.tolist())  # Check actual column names first!

# Suppose actual columns are lowercase and with underscore:
features = df.drop(['target', 'failure_type'], axis=1)

iso = IsolationForest(contamination=0.05)
df['anomaly'] = iso.fit_predict(features)

sns.scatterplot(x='Rotational speed [rpm]', y='Torque [Nm]', hue='anomaly', data=df)
plt.title('Anomaly Detection')
plt.show()
# Out:
# ['Type', 'Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Machine failure', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 11
#       8 print(df.columns.tolist())  # Check actual column names first!
#      10 # Suppose actual columns are lowercase and with underscore:
# ---> 11 features = df.drop(['target', 'failure_type'], axis=1)
#      13 iso = IsolationForest(contamination=0.05)
#      14 df['anomaly'] = iso.fit_predict(features)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
# ...

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\Naresh\OneDrive\Desktop\Rooman\ai4i2020_cleaned.csv')

print(df.columns.tolist())  # Check actual column names first!

# Suppose actual columns are lowercase and with underscore:
features = df.drop(['target', 'failure_type'], axis=1)

iso = IsolationForest(contamination=0.05)
df['anomaly'] = iso.fit_predict(features)

sns.scatterplot(x='Rotational speed [rpm]', y='Torque [Nm]', hue='anomaly', data=df)
plt.title('Anomaly Detection')
plt.show()
# Out:
# ['Type', 'Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Machine failure', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 11
#       8 print(df.columns.tolist())  # Check actual column names first!
#      10 # Suppose actual columns are lowercase and with underscore:
# ---> 11 features = df.drop(['target', 'failure_type'], axis=1)
#      13 iso = IsolationForest(contamination=0.05)
#      14 df['anomaly'] = iso.fit_predict(features)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
# ...

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
import seaborn as sns
import matplotlib.pyplot as plt

# Read the cleaned dataset
df = pd.read_csv(r'C:\Users\Naresh\OneDrive\Desktop\Rooman\ai4i2020_cleaned.csv')

# Check the columns present in the DataFrame
print("Columns in dataset:", df.columns.tolist())

# Columns you want to drop if they exist
cols_to_drop = ['Target', 'Failure Type']

# Keep only the columns that exist in df
existing_cols = [col for col in cols_to_drop if col in df.columns]

# Drop existing columns safely
features = df.drop(existing_cols, axis=1)

# Initialize Isolation Forest for anomaly detection
iso = IsolationForest(contamination=0.05, random_state=42)
df['anomaly'] = iso.fit_predict(features)

# Plot anomalies detected
sns.scatterplot(x='Rotational speed [rpm]', y='Torque [Nm]', hue='anomaly', data=df)
plt.title('Anomaly Detection')
plt.show()
# Out:
# Columns in dataset: ['Type', 'Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Machine failure', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF']
